# %% [markdown]
# # 1. Build graph using TF operations

# %%
import tensorflow as tf
# training data
x_train = [1, 2, 3]
y_train = [1, 2, 3]

# W, b를 정의
# tensorflow가 사용하는 변수, tensorflow가 학습하는 과정에서 변경(trainable한 변수)
# 최초 랜덤값으로 설정
# tf.random_normal([1] : rank가 1인 랜덤값 생성
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# hypothesis XW+b
hypothesis = x_train*W + b
# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis-y_train))

# Minimize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01) # GradientDescentOptimizer : minimize 방법 중 하나 
train = optimizer.minimize(cost)

# %% [markdown]
# ## 2, 3. Run/update graph and get results

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer()) # variable을 사용하기 이전에는 초기화해주어야 함

for step in range(2001):
    sess.run(train)
    if(step%20) == 0:
      print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 1.27574 [ 0.82724488] [ 1.46615553]
# 20 0.226919 [ 0.49598452] [ 1.24795806]
# 40 0.197644 [ 0.48735595] [ 1.17509294]
# 60 0.179427 [ 0.50837123] [ 1.11851454]
# 80 0.162958 [ 0.53118289] [ 1.06581962]
# 100 0.148001 [ 0.55318767] [ 1.01571774]
# 120 0.134417 [ 0.57418352] [ 0.9679817]
# 140 0.12208 [ 0.59419513] [ 0.92249]
# 160 0.110875 [ 0.61326641] [ 0.87913626]
# 180 0.100698 [ 0.63144147] [ 0.83782023]
# 200 0.0914556 [ 0.64876235] [ 0.79844582]
# 220 0.0830614 [ 0.66526926] [ 0.76092184]
# 240 0.0754377 [ 0.68100035] [ 0.72516125]
# 260 0.0685138 [ 0.69599217] [ 0.69108129]
# 280 0.0622253 [ 0.71027941] [ 0.65860295]
# 300 0.056514 [ 0.72389519] [ 0.62765104]
# 320 0.0513269 [ 0.73687118] [ 0.59815377]
# 340 0.0466159 [ 0.74923718] [ 0.57004285]
# 360 0.0423373 [ 0.76102215] [ 0.54325289]
# 380 0.0384514 [ 0.77225322] [ 0.51772207]
# 400 0.0349222 [ 0.78295642] [ 0.49339107]
# 420 0.0317169 [ 0.79315668] [ 0.47020349]
# 440 0.0288058 [ 0.80287755] [ 0.44810566]
# ...
